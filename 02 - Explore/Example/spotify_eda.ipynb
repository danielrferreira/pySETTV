# %% [markdown]
# # Spotify Exploratory Analysis using EDA Aid

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
import importlib
from sklearn.ensemble import RandomForestClassifier
import eda_aid as ea

# %%
path = '/Users/danielferreira/Documents/git/pySETTV/02 - Explore/Example/'
file =  'billboard_24years_lyrics_spotify.csv'
df = pd.read_csv(path+file)
df['ranking_5'] = df['ranking']<6

# %%
ed = ea.eda_aid(df)
# Out:
# EDA Aid initialized with 3397 rows and 27 columns:
#  - Numeric: 15
#  - Object: 11
#  - Boolean: 1
#  - Datetime: 0

# %%
ed.columns_df()
# Out:
#                      type  missing_count  missing_proportions  \
# name
# ranking           numeric              0                0.000
# year              numeric              0                0.000
# danceability      numeric           2911                0.857
# energy            numeric           2911                0.857
# key               numeric           2911                0.857
# loudness          numeric           2911                0.857
# mode              numeric           2911                0.857
# speechiness       numeric           2911                0.857
# acousticness      numeric           2911                0.857
# instrumentalness  numeric           2911                0.857
# liveness          numeric           2911                0.857
# valence           numeric           2911                0.857
# tempo             numeric           2911                0.857
# duration_ms       numeric           2911                0.857
# ...

# %%
ed.missingness_chi_whitin()

# %%
ed.missingness_association()

# %%
ed.ln_analysis('ranking_5')
# Out:
# ----------------------------------------------------------------------------------------------------
# ranking_5 vs ranking -> rem_ol=False
# ----------------------------------------------------------------------------------------------------
# 0 = (0.901, 10.9]
# 1 = (10.9, 20.8]
# 2 = (20.8, 30.7]
# 3 = (30.7, 40.6]
# 4 = (40.6, 50.5]
# 5 = (50.5, 60.4]
# 6 = (60.4, 70.3]
# 7 = (70.3, 80.2]
# 8 = (80.2, 90.1]
# 9 = (90.1, 100.0]
# ----------------------------------------------------------------------------------------------------
# ranking_5 vs year -> rem_ol=False
# ----------------------------------------------------------------------------------------------------
# 0 = (1999.977, 2002.3]
# 1 = (2002.3, 2004.6]
# 2 = (2004.6, 2006.9]
# 3 = (2006.9, 2009.2]
# 4 = (2009.2, 2011.5]
# 5 = (2011.5, 2013.8]
# 6 = (2013.8, 2016.1]
# 7 = (2016.1, 2018.4]
# 8 = (2018.4, 2020.7]
# 9 = (2020.7, 2023.0]

# %%
print(ed.numeric_list)
print(ed.categorical_list)
print(ed.boolean_list)
print(ed.datetime_list)
# Out:
# ['ranking', 'year', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms', 'time_signature']
# ['song', 'band_singer', 'songurl', 'titletext', 'url', 'lyrics', 'uri', 'type', 'id', 'track_href', 'analysis_url']
# ['ranking_5']
# []

# %%
ed.eda_quant_uni()

# %%
cols = ['ranking', 'year', 'danceability', 'energy', 'loudness', 
       'speechiness', 'acousticness', 'liveness',
       'valence', 'tempo', 'duration_ms']
ed.eda_quant_uni(cols)

# %%
ed.eda_quant_uni(cols, type='violin')

# %%
ed.eda_quant_uni(cols, type='box')

# %%
ed.eda_cat_uni()
# Out:
# WARNING: Column song removed due to high-cardinality (2080 unique elements)
# WARNING: Column band_singer removed due to high-cardinality (1039 unique elements)
# WARNING: Column songurl removed due to high-cardinality (2172 unique elements)
# WARNING: Column titletext removed due to high-cardinality (2078 unique elements)
# WARNING: Column url removed due to high-cardinality (1042 unique elements)
# WARNING: Column lyrics removed due to high-cardinality (2330 unique elements)
# WARNING: Column uri removed due to high-cardinality (2319 unique elements)
# WARNING: Column id removed due to high-cardinality (457 unique elements)
# WARNING: Column track_href removed due to high-cardinality (457 unique elements)
# WARNING: Column analysis_url removed due to high-cardinality (457 unique elements)

# %%
ed.eda_date_uni()
# Out:
# 'No date variables'

# %%
ed.eda_cat_vs_quant_bi('ranking_5')

# %%
ed.eda_cat_vs_cat_bi('ranking_5')
# Out:
# WARNING: Column song removed due to high-cardinality (2080 unique elements)
# WARNING: Column band_singer removed due to high-cardinality (1039 unique elements)
# WARNING: Column songurl removed due to high-cardinality (2172 unique elements)
# WARNING: Column titletext removed due to high-cardinality (2078 unique elements)
# WARNING: Column url removed due to high-cardinality (1042 unique elements)
# WARNING: Column lyrics removed due to high-cardinality (2330 unique elements)
# WARNING: Column uri removed due to high-cardinality (2319 unique elements)
# WARNING: Column id removed due to high-cardinality (457 unique elements)
# WARNING: Column track_href removed due to high-cardinality (457 unique elements)
# WARNING: Column analysis_url removed due to high-cardinality (457 unique elements)

# %%
ed.cat_bivariate(['type','key'],['ranking_5'])
# Out:
# type vs ranking_5
# Chi-squared: 0.0
# p-value: 1.0
# key vs ranking_5
# Chi-squared: 11.07
# p-value: 0.4378
